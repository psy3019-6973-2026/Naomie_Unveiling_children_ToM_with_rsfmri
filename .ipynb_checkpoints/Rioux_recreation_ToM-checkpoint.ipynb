# %% [markdown]
# ## Modification #1 - Import NiftiLabelsMasker
# **Avertissement original :** FutureWarning — `nilearn.input_data` est déprécié depuis la version 0.9
# **Changement :** Mise à jour du chemin d'import
# **Pourquoi :** Bonne pratique pour compatibilité future

# %%
# Install the needed packages
# !pip install nilearn
from nilearn import datasets

#code original
#from nilearn.input_data import NiftiLabelsMasker
from nilearn.maskers import NiftiLabelsMasker

from nilearn.connectome import ConnectivityMeasure
from nilearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# Out:
# Requirement already satisfied: nilearn in /home/nrioux/miniconda3/lib/python3.13/site-packages (0.13.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from nilearn) (3.1.6)
# Requirement already satisfied: joblib>=1.2.0 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from nilearn) (1.5.3)
# Requirement already satisfied: nibabel>=5.2.0 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from nilearn) (5.3.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from nilearn) (2.4.1)
# Requirement already satisfied: packaging in /home/nrioux/miniconda3/lib/python3.13/site-packages (from nilearn) (25.0)
# Requirement already satisfied: pandas>=2.2.0 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from nilearn) (2.3.3)
# Requirement already satisfied: requests>=2.30.0 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from nilearn) (2.32.5)
# Requirement already satisfied: scikit-learn>=1.4.0 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from nilearn) (1.8.0)
# Requirement already satisfied: scipy>=1.9.0 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from nilearn) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from jinja2>=3.1.2->nilearn) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from pandas>=2.2.0->nilearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from pandas>=2.2.0->nilearn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from pandas>=2.2.0->nilearn) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->nilearn) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from requests>=2.30.0->nilearn) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from requests>=2.30.0->nilearn) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from requests>=2.30.0->nilearn) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from requests>=2.30.0->nilearn) (2026.1.4)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/nrioux/miniconda3/lib/python3.13/site-packages (from scikit-learn>=1.4.0->nilearn) (3.6.0)

# %%
# import the behavioral dataset
url = "https://github.com/WeiHungLin/BHS_project/raw/main/participants_childrenonly.csv"
df_behav = pd.read_csv(url)
df_behav
# Out:
#     participant_id        Age AgeGroup Child_Adult Gender Handedness  \
# 0     sub-pixar001   4.774812      4yo       child      M          R
# 1     sub-pixar002   4.856947      4yo       child      F          R
# 2     sub-pixar003   4.153320      4yo       child      F          R
# 3     sub-pixar004   4.473648      4yo       child      F          R
# 4     sub-pixar005   4.837782      4yo       child      F          R
# ..             ...        ...      ...         ...    ...        ...
# 117   sub-pixar118  10.500000   8-12yo       child      F          R
# 118   sub-pixar119   8.620000   8-12yo       child      F          R
# 119   sub-pixar120  11.480000   8-12yo       child      F          R
# 120   sub-pixar121   8.760000   8-12yo       child      F          R
# 121   sub-pixar122   7.210000      7yo       child      M          R
#
#      ToM Booklet-Matched  ToM Booklet-Matched-NOFB  FB_Composite FB_Group  \
# 0                   0.80                  0.736842             6     pass
# 1                   0.72                  0.736842             4      inc
# 2                   0.44                  0.421053             3      inc
# 3                   0.64                  0.736842             2     fail
# 4                   0.60                  0.578947             4      inc
# ..                   ...                       ...           ...      ...
# 117                 1.00                  1.000000             6     pass
# 118                 1.00                  1.000000             5     pass
# 119                 1.00                  1.000000             5     pass
# 120                 1.00                  1.000000             6     pass
# 121                 1.00                  1.000000             6     pass
#
#      WPPSI BD raw  WPPSI BD scaled  KBIT_raw  KBIT_standard  DCCS Summary  \
# 0            22.0             13.0       NaN            NaN           3.0
# 1            18.0              9.0       NaN            NaN           2.0
# 2            15.0              9.0       NaN            NaN           3.0
# 3            17.0             10.0       NaN            NaN           3.0
# 4            13.0              5.0       NaN            NaN           2.0
# ..            ...              ...       ...            ...           ...
# 117           NaN              NaN      37.0          119.0           NaN
# 118           NaN              NaN      33.0          121.0           NaN
# 119           NaN              NaN      38.0          117.0           NaN
# 120           NaN              NaN      37.0          130.0           NaN
# 121           NaN              NaN      31.0          119.0           NaN
#
#     Scanlog: Scanner Scanlog: Coil Scanlog: Voxel slize  Scanlog: Slice Gap
# 0                3T1    7-8yo 32ch              3mm iso                 0.1
# 1                3T1    7-8yo 32ch              3mm iso                 0.1
# 2                3T1    7-8yo 32ch              3mm iso                 0.1
# 3                3T1    7-8yo 32ch              3mm iso                 0.2
# 4                3T1    7-8yo 32ch              3mm iso                 0.2
# ..               ...           ...                  ...                 ...
# 117              3T1    32ch adult          3.13 mm iso                 NaN
# 118              3T1    32ch adult          3.13 mm iso                 NaN
# 119              3T1    32ch adult          3.13 mm iso                 NaN
# 120              3T1    32ch adult          3.13 mm iso                 NaN
# 121              3T1    32ch adult              3mm iso                 0.2
#
# [122 rows x 19 columns]

# %%
participant_df = pd.DataFrame({
    'Number': [122],
    'Age Mean': [6.71],
    'Age Range': ["3 - 12"],
    'ToM Mean': [0.775],
    'ToM Range':["0.24 - 1"]
}, index = [0])


styled_participant_df = participant_df.style.set_properties(**{'background-color': 'lightblue',
                                       'color': 'black',
                                       'font-family': 'Arial',
                                       'text-align': 'center'})

# %%
styled_participant_df
# Out:
# <style type="text/css">
# #T_02169_row0_col0, #T_02169_row0_col1, #T_02169_row0_col2, #T_02169_row0_col3, #T_02169_row0_col4 {
#   background-color: lightblue;
#   color: black;
#   font-family: Arial;
#   text-align: center;
# }
# </style>
# <table id="T_02169">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02169_level0_col0" class="col_heading level0 col0" >Number</th>
#       <th id="T_02169_level0_col1" class="col_heading level0 col1" >Age Mean</th>
#       <th id="T_02169_level0_col2" class="col_heading level0 col2" >Age Range</th>
#       <th id="T_02169_level0_col3" class="col_heading level0 col3" >ToM Mean</th>
#       <th id="T_02169_level0_col4" class="col_heading level0 col4" >ToM Range</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02169_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_02169_row0_col0" class="data row0 col0" >122</td>
#       <td id="T_02169_row0_col1" class="data row0 col1" >6.710000</td>
#       <td id="T_02169_row0_col2" class="data row0 col2" >3 - 12</td>
#       <td id="T_02169_row0_col3" class="data row0 col3" >0.775000</td>
#       <td id="T_02169_row0_col4" class="data row0 col4" >0.24 - 1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# fetch the preprocessed rs-fMRI dataset
data = datasets.fetch_development_fmri()
# Out:
# [fetch_development_fmri] Dataset found in /home/nrioux/nilearn_data/development_fmri
# [fetch_development_fmri] Dataset found in /home/nrioux/nilearn_data/development_fmri/development_fmri
# [fetch_development_fmri] Dataset found in /home/nrioux/nilearn_data/development_fmri/development_fmri

# %%
# Check the dataset size
len(data.func)
# Out:
# 155

# %% [markdown]
# # Modification 2: changement d'atlas

# %% [markdown]
# ## Bug #1 - Réduction des régions
# Problème : 400 régions × 122 sujets dépasse la RAM
# Solution : Réduire à 100 régions avec n_rois=100
#
# ## Bug #2 - Réduction du nombre de participants
# Problème: dépasse toujours le RAM même avec 100 rois
# Solution: utilisé 50 participants

# %%
from nilearn import datasets

parcellations = datasets.fetch_atlas_schaefer_2018(n_rois=100)
atlas_filename = parcellations.maps

#masker = NiftiLabelsMasker(labels_img = atlas_filename,
#                           standardize = True,
#                           memory = 'nilearn_cache',
#                           verbose = 0)

masker = NiftiLabelsMasker(labels_img=atlas_filename,
                           standardize='zscore_sample',  # ← à jour
                           memory='nilearn_cache',
                           verbose=0)

correlation_measure = ConnectivityMeasure(kind='correlation',
                      vectorize=True,
                      discard_diagonal=True,
                      standardize='zscore_sample')
# Out:
# [fetch_atlas_schaefer_2018] Dataset found in /home/nrioux/nilearn_data/schaefer_2018

# %%
# Create the correlation matrix for all children
all_features = []

for i,sub in enumerate(data.func):
  if i > 32 and i < 73:  # 40 enfants seulement (sujets 33 à 82)
    # Extract the timeseries from the ROIs in the atlas
    time_series = masker.fit_transform(sub, confounds = data.confounds[i])
    # Create a correlation matrix
    correlation_matrix = correlation_measure.fit_transform([time_series])[0]
    # Add to the list
    all_features.append(correlation_matrix)
    # Kepp track of the progress
    print('finished %s of %s'%((i+1),len(data.func)))
  else:
    continue
# Out:
# finished 34 of 155
# finished 35 of 155
# finished 36 of 155
# finished 37 of 155
# finished 38 of 155
# finished 39 of 155
# finished 40 of 155
# finished 41 of 155
# finished 42 of 155
# finished 43 of 155
# finished 44 of 155
# finished 45 of 155
# finished 46 of 155
# finished 47 of 155
# finished 48 of 155
# finished 49 of 155
# finished 50 of 155
# finished 51 of 155
# finished 52 of 155
# finished 53 of 155
# finished 54 of 155
# finished 55 of 155
# finished 56 of 155
# finished 57 of 155
# finished 58 of 155
# finished 59 of 155
# finished 60 of 155
# finished 61 of 155
# finished 62 of 155
# finished 63 of 155
# finished 64 of 155
# finished 65 of 155
# finished 66 of 155
